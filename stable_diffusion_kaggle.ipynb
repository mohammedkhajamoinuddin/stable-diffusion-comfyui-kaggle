# %%
# !git clone https://github.com/comfyanonymous/ComfyUI.git
# %cd ComfyUI

# %%
# !pip install -r requirements.txt
# !pip install pyngrok
# Out:
# Collecting comfyui-frontend-package==1.53.6 (from -r requirements.txt (line 1))
#   Downloading comfyui_frontend_package-1.53.6-py3-none-any.whl.metadata (117 bytes)
# Collecting comfyui-workflow-templates==0.11.69 (from -r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates-0.11.69-py3-none-any.whl.metadata (24 kB)
# Collecting comfyui-embedded-docs==0.5.12 (from -r requirements.txt (line 3))
#   Downloading comfyui_embedded_docs-0.5.12-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.10.0+cu128)
# Collecting torchsde (from -r requirements.txt (line 5))
#   Downloading torchsde-0.2.6-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (0.25.0+cu128)
# Requirement already satisfied: numpy>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (2.0.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (0.8.2)
# Requirement already satisfied: transformers>=4.50.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (5.0.0)
# Requirement already satisfied: tokenizers>=0.13.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (0.22.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (0.2.1)
# Requirement already satisfied: safetensors>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (0.7.0)
# Requirement already satisfied: aiohttp>=3.11.8 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (3.13.5)
# Requirement already satisfied: yarl>=1.18.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (1.23.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (6.0.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (1.16.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 18)) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 19)) (5.9.5)
# Requirement already satisfied: alembic in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 20)) (1.18.4)
# Requirement already satisfied: SQLAlchemy>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 21)) (2.0.49)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 22)) (3.29.0)
# Collecting av>=17.0.0 (from -r requirements.txt (line 23))
#   Downloading av-18.1.0-cp311-abi3-manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Collecting comfy-kitchen==0.2.35 (from -r requirements.txt (line 24))
#   Downloading comfy_kitchen-0.2.35-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (15 kB)
# Collecting comfy-aimdo==0.5.5 (from -r requirements.txt (line 25))
#   Downloading comfy_aimdo-0.5.5-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 26)) (2.32.4)
# Collecting simpleeval>=1.0.0 (from -r requirements.txt (line 27))
#   Downloading simpleeval-1.0.8-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: blake3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 28)) (1.0.9)
# Requirement already satisfied: kornia>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 31)) (0.8.3)
# Collecting spandrel (from -r requirements.txt (line 32))
#   Downloading spandrel-0.4.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pydantic~=2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 33)) (2.12.3)
# Requirement already satisfied: pydantic-settings~=2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 34)) (2.14.0)
# Requirement already satisfied: PyOpenGL>=3.1.8 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 35)) (3.1.10)
# Collecting comfy-angle (from -r requirements.txt (line 36))
#   Downloading comfy_angle-0.1.1-py3-none-manylinux_2_28_x86_64.whl.metadata (2.2 kB)
# Collecting comfyui-workflow-templates-core==0.3.360 (from comfyui-workflow-templates==0.11.69->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_core-0.3.360-py3-none-any.whl.metadata (260 bytes)
# Collecting comfyui-workflow-templates-json==0.1.95 (from comfyui-workflow-templates==0.11.69->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_json-0.1.95-py3-none-any.whl.metadata (265 bytes)
# Collecting comfyui-workflow-templates-media-api==0.3.84 (from comfyui-workflow-templates==0.11.69->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_api-0.3.84-py3-none-any.whl.metadata (290 bytes)
# Collecting comfyui-workflow-templates-media-video==0.3.101 (from comfyui-workflow-templates==0.11.69->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_video-0.3.101-py3-none-any.whl.metadata (283 bytes)
# Collecting comfyui-workflow-templates-media-image==0.3.160 (from comfyui-workflow-templates==0.11.69->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_image-0.3.160-py3-none-any.whl.metadata (283 bytes)
# Collecting comfyui-workflow-templates-media-other==0.3.229 (from comfyui-workflow-templates==0.11.69->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_other-0.3.229-py3-none-any.whl.metadata (306 bytes)
# Collecting comfyui-workflow-templates-media-assets-01==0.1.48 (from comfyui-workflow-templates==0.11.69->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_assets_01-0.1.48-py3-none-any.whl.metadata (290 bytes)
# Collecting comfyui-workflow-templates-media-assets-02==0.1.5 (from comfyui-workflow-templates==0.11.69->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_assets_02-0.1.5-py3-none-any.whl.metadata (289 bytes)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->-r requirements.txt (line 4)) (1.5.3)
# Collecting trampoline>=0.1.2 (from torchsde->-r requirements.txt (line 5))
#   Downloading trampoline-0.1.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 9)) (1.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 9)) (26.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 9)) (2025.11.3)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 9)) (0.24.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 13)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 13)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 13)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 13)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 13)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 13)) (0.4.1)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl>=1.18.0->-r requirements.txt (line 14)) (3.13)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic->-r requirements.txt (line 20)) (1.3.11)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy>=2.0.0->-r requirements.txt (line 21)) (3.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 26)) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 26)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 26)) (2026.4.22)
# Requirement already satisfied: kornia-rs>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from kornia>=0.7.1->-r requirements.txt (line 31)) (0.1.14)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->-r requirements.txt (line 33)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->-r requirements.txt (line 33)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->-r requirements.txt (line 33)) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings~=2.0->-r requirements.txt (line 34)) (1.2.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 9)) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 9)) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 9)) (0.24.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 9)) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 9)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 9)) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 9)) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 9)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 9)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 9)) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 9)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 9)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 9)) (0.1.2)
# Downloading comfyui_frontend_package-1.53.6-py3-none-any.whl (25.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.2/25.2 MB 65.6 MB/s eta 0:00:00:00:0100:01
# Downloading comfyui_workflow_templates-0.11.69-py3-none-any.whl (10 kB)
# Downloading comfyui_embedded_docs-0.5.12-py3-none-any.whl (19.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 71.6 MB/s eta 0:00:00:00:0100:01
# Downloading comfy_kitchen-0.2.35-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (47.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 MB 40.6 MB/s eta 0:00:00:00:0100:01
# Downloading comfy_aimdo-0.5.5-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (432 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 432.7/432.7 kB 29.9 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_core-0.3.360-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.7/77.7 kB 6.5 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_json-0.1.95-py3-none-any.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 59.4 MB/s eta 0:00:00a 0:00:01
# Downloading comfyui_workflow_templates_media_api-0.3.84-py3-none-any.whl (100.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 17.8 MB/s eta 0:00:0000:0100:01
# Downloading comfyui_workflow_templates_media_assets_01-0.1.48-py3-none-any.whl (94.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.2/94.2 MB 16.2 MB/s eta 0:00:0000:0100:01
# Downloading comfyui_workflow_templates_media_assets_02-0.1.5-py3-none-any.whl (9.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 45.9 MB/s eta 0:00:0000:0100:01
# Downloading comfyui_workflow_templates_media_image-0.3.160-py3-none-any.whl (89.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.4/89.4 MB 17.6 MB/s eta 0:00:0000:0100:01
# Downloading comfyui_workflow_templates_media_other-0.3.229-py3-none-any.whl (89.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 MB 17.3 MB/s eta 0:00:0000:0100:01
# Downloading comfyui_workflow_templates_media_video-0.3.101-py3-none-any.whl (104.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 15.7 MB/s eta 0:00:0000:010:01
# Downloading torchsde-0.2.6-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 4.2 MB/s eta 0:00:00
# Downloading av-18.1.0-cp311-abi3-manylinux_2_28_x86_64.whl (35.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.8/35.8 MB 35.3 MB/s eta 0:00:0000:0100:01
# Downloading simpleeval-1.0.8-py3-none-any.whl (18 kB)
# Downloading spandrel-0.4.2-py3-none-any.whl (320 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.8/320.8 kB 22.8 MB/s eta 0:00:00
# Downloading comfy_angle-0.1.1-py3-none-manylinux_2_28_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 48.0 MB/s eta 0:00:0000:0100:01
# Downloading trampoline-0.1.2-py3-none-any.whl (5.2 kB)
# Installing collected packages: trampoline, simpleeval, comfyui-workflow-templates-media-video, comfyui-workflow-templates-media-other, comfyui-workflow-templates-media-image, comfyui-workflow-templates-media-assets-02, comfyui-workflow-templates-media-assets-01, comfyui-workflow-templates-media-api, comfyui-workflow-templates-json, comfyui-workflow-templates-core, comfyui-frontend-package, comfyui-embedded-docs, comfy-kitchen, comfy-angle, comfy-aimdo, av, comfyui-workflow-templates, torchsde, spandrel
# Successfully installed av-18.1.0 comfy-aimdo-0.5.5 comfy-angle-0.1.1 comfy-kitchen-0.2.35 comfyui-embedded-docs-0.5.12 comfyui-frontend-package-1.53.6 comfyui-workflow-templates-0.11.69 comfyui-workflow-templates-core-0.3.360 comfyui-workflow-templates-json-0.1.95 comfyui-workflow-templates-media-api-0.3.84 comfyui-workflow-templates-media-assets-01-0.1.48 comfyui-workflow-templates-media-assets-02-0.1.5 comfyui-workflow-templates-media-image-0.3.160 comfyui-workflow-templates-media-other-0.3.229 comfyui-workflow-templates-media-video-0.3.101 simpleeval-1.0.8 spandrel-0.4.2 torchsde-0.2.6 trampoline-0.1.2
# Collecting pyngrok
#   Downloading pyngrok-8.1.2-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from pyngrok) (6.0.3)
# Downloading pyngrok-8.1.2-py3-none-any.whl (25 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-8.1.2

# %%
# !mkdir -p models/checkpoints

# !wget -O models/checkpoints/v1-5-pruned-emaonly.safetensors \
https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.safetensors
# Out:
# --2026-09-24 13:07:36--  https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.safetensors
# Resolving huggingface.co (huggingface.co)... 13.226.251.112, 13.226.251.66, 13.226.251.81, ...
# Connecting to huggingface.co (huggingface.co)|13.226.251.112|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: /stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.safetensors [following]
# --2026-09-24 13:07:36--  https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.safetensors
# Reusing existing connection to huggingface.co:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://us.gcp.cdn.hf.co/xet-bridge-us/66d19580e2632490a6bc5829/2ac63bfb6186057d88b65c3aa47ec90fd8d9aa3269164fc37fed1cb6f1a1efd0?user_id=public&response-content-disposition=inline%3B+filename*%3DUTF-8%27%27v1-5-pruned-emaonly.safetensors%3B+filename%3D%22v1-5-pruned-emaonly.safetensors%22%3B&X-Xet-Cas-Uid=public&Expires=1790258856&Policy=&Signature=MEYCIQDUBvYEj7%7EdMjU7YsVhsrXdb5xbTDZVf2MQE-9XVIJ8HAIhAKqyqphSF9A1KB6Hmfq0Ap7Fq0yRrE13EKRxb63Q2ufu&Key-Pair-Id=01KXEF4KZ1B6FV465MAWR4M21F&Hash-Algorithm=SHA256 [following]
# --2026-09-24 13:07:36--  https://us.gcp.cdn.hf.co/xet-bridge-us/66d19580e2632490a6bc5829/2ac63bfb6186057d88b65c3aa47ec90fd8d9aa3269164fc37fed1cb6f1a1efd0?user_id=public&response-content-disposition=inline%3B+filename*%3DUTF-8%27%27v1-5-pruned-emaonly.safetensors%3B+filename%3D%22v1-5-pruned-emaonly.safetensors%22%3B&X-Xet-Cas-Uid=public&Expires=1790258856&Policy=&Signature=MEYCIQDUBvYEj7%7EdMjU7YsVhsrXdb5xbTDZVf2MQE-9XVIJ8HAIhAKqyqphSF9A1KB6Hmfq0Ap7Fq0yRrE13EKRxb63Q2ufu&Key-Pair-Id=01KXEF4KZ1B6FV465MAWR4M21F&Hash-Algorithm=SHA256
# Resolving us.gcp.cdn.hf.co (us.gcp.cdn.hf.co)... 34.8.125.20
# Connecting to us.gcp.cdn.hf.co (us.gcp.cdn.hf.co)|34.8.125.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4265146304 (4.0G) [application/octet-stream]
# Saving to: ‘models/checkpoints/v1-5-pruned-emaonly.safetensors’
#
# models/checkpoints/ 100%[===================>]   3.97G  44.8MB/s    in 76s
#
# 2026-09-24 13:08:53 (53.2 MB/s) - ‘models/checkpoints/v1-5-pruned-emaonly.safetensors’ saved [4265146304/4265146304]

# %%
import subprocess
import threading

def run():
    subprocess.run([
        "python",
        "main.py",
        "--listen",
        "0.0.0.0",
        "--port",
        "8188"
    ])

threading.Thread(target=run, daemon=True).start()
# Out:
# [INFO] setup plugin alembic.autogenerate.schemas
# [INFO] setup plugin alembic.autogenerate.tables
# [INFO] setup plugin alembic.autogenerate.types
# [INFO] setup plugin alembic.autogenerate.constraints
# [INFO] setup plugin alembic.autogenerate.defaults
# [INFO] setup plugin alembic.autogenerate.comments
# [WARNING] WARNING: You need pytorch with cu130 or higher to use optimized CUDA operations.
# WARNING WARNING WARNING
# If you are on nvidia 20 series and above it is required that you update your pytorch to cu130 or higher.
#
# [INFO] Found comfy_kitchen backend triton: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['adaln', 'apply_rope', 'apply_rope1', 'apply_rope1_', 'apply_rope_', 'apply_rope_split_half', 'apply_rope_split_half1', 'apply_rope_split_half1_', 'apply_rope_split_half_', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'int8_linear', 'na3d', 'quantize_and_rotate_rowwise', 'quantize_int8_rowwise', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'rms_adaln', 'rms_rope', 'rms_rope1', 'rms_rope1_', 'rms_rope_', 'rms_rope_split_half', 'rms_rope_split_half1', 'rms_rope_split_half1_', 'rms_rope_split_half_', 'w4a8_int8_linear']}
# [INFO] Found comfy_kitchen backend eager: {'available': True, 'disabled': False, 'unavailable_reason': None, 'capabilities': ['adaln', 'apply_rope', 'apply_rope1', 'apply_rope1_', 'apply_rope_', 'apply_rope_split_half', 'apply_rope_split_half1', 'apply_rope_split_half1_', 'apply_rope_split_half_', 'convrot_w4a4_linear', 'dequantize_convrot_w4a4_weight', 'dequantize_int8_convrot_weight', 'dequantize_int8_convrot_weight_dtype', 'dequantize_int8_embedding', 'dequantize_int8_simple', 'dequantize_int8_simple_dtype', 'dequantize_mxfp8', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'dequantize_w4a8_int8_weight', 'fp16_conv3d', 'fp16_linear', 'gemv_awq_w4a16', 'group_norm_silu_pad3d', 'int8_linear', 'na3d', 'prepare_int4_weight_for_int8_linear', 'quantize_and_rotate_rowwise', 'quantize_convrot_w4a4_weight', 'quantize_int8_convrot_weight', 'quantize_int8_rowwise', 'quantize_int8_tensorwise', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'quantize_svdquant_w4a4', 'quantize_w4a8_int8_weight', 'rms_adaln', 'rms_rope', 'rms_rope1', 'rms_rope1_', 'rms_rope_', 'rms_rope_split_half', 'rms_rope_split_half1', 'rms_rope_split_half1_', 'rms_rope_split_half_', 'rotate_int8_convrot_weight', 'scaled_mm_mxfp8', 'scaled_mm_nvfp4', 'scaled_mm_svdquant_w4a4', 'sol_attn', 'stochastic_rounding_fp8', 'w4a8_int8_linear']}
# [INFO] Found comfy_kitchen backend hip: {'available': False, 'disabled': False, 'unavailable_reason': 'PyTorch ROCm/HIP runtime not available', 'capabilities': []}
# [INFO] Found comfy_kitchen backend cuda: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['adaln', 'apply_rope', 'apply_rope1', 'apply_rope1_', 'apply_rope_', 'apply_rope_split_half', 'apply_rope_split_half1', 'apply_rope_split_half1_', 'apply_rope_split_half_', 'convrot_w4a4_linear', 'dequantize_convrot_w4a4_weight', 'dequantize_int8_convrot_weight', 'dequantize_int8_convrot_weight_dtype', 'dequantize_int8_simple', 'dequantize_int8_simple_dtype', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'dequantize_w4a8_int8_weight', 'fp16_conv3d', 'fp16_linear', 'gemv_awq_w4a16', 'group_norm_silu_pad3d', 'int8_linear', 'na3d', 'prepare_int4_weight_for_int8_linear', 'quantize_and_rotate_rowwise', 'quantize_convrot_w4a4_weight', 'quantize_int8_convrot_weight', 'quantize_int8_rowwise', 'quantize_int8_tensorwise', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'quantize_svdquant_w4a4', 'quantize_w4a8_int8_weight', 'rms_adaln', 'rms_rope', 'rms_rope1', 'rms_rope1_', 'rms_rope_', 'rms_rope_split_half', 'rms_rope_split_half1', 'rms_rope_split_half1_', 'rms_rope_split_half_', 'rotate_int8_convrot_weight', 'scaled_mm_nvfp4', 'scaled_mm_svdquant_w4a4', 'sol_attn', 'stochastic_rounding_fp8', 'w4a8_int8_linear']}
# [INFO] Checkpoint files will always be loaded safely.
# [INFO] Total VRAM 14912 MB, total RAM 30720 MB
# [INFO] RAM limited by cgroup to 30720 MB (host has 32100 MB)
# [INFO] pytorch version: 2.10.0+cu128
# [INFO] Set vram state to: NORMAL_VRAM
# [INFO] Device: cuda:0 Tesla T4 : cudaMallocAsync
# [INFO] Device: cuda:1 Tesla T4 : cudaMallocAsync
# [INFO] Using async weight offloading with 2 streams
# [INFO] Enabled pinned memory 14336
# [INFO] working around nvidia conv3d memory bug.
# [INFO] Using pytorch attention
# [INFO] aimdo: /project/src/control.c:283:INFO:comfy-aimdo inited for GPU: Tesla T4 (VRAM: 14911 MB)
# [INFO] aimdo: /project/src/control.c:283:INFO:comfy-aimdo inited for GPU: Tesla T4 (VRAM: 14911 MB)
# [INFO] DynamicVRAM support detected and enabled
# [INFO] Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# [INFO] ComfyUI version: 0.37.0
# [INFO] comfy-aimdo version: 0.5.5
# [INFO] comfy-kitchen version: 0.2.35
# [WARNING] ****** User settings have been changed to be stored on the server instead of browser storage. ******
# [WARNING] ****** For multi-user setups add the --multi-user CLI argument to enable multiple user profiles. ******
# [INFO] comfyui-frontend-package version: 1.53.6
# [INFO] comfyui-workflow-templates version: 0.11.69
# [INFO] comfyui-embedded-docs version: 0.5.12
# [INFO] comfy-kitchen version: 0.2.35
# [INFO] comfy-aimdo version: 0.5.5
# [INFO] [Prompt Server] web root: /usr/local/lib/python3.12/dist-packages/comfyui_frontend_package/static
# [INFO] Asset seeder disabled
# [INFO] No OpenGL_accelerate module loaded: No module named 'OpenGL_accelerate'
# [INFO]
# Import times for custom nodes:
# [INFO]    0.0 seconds: /kaggle/working/ComfyUI/custom_nodes/websocket_image_save.py
# [INFO]
# [INFO] Context impl SQLiteImpl.
# [INFO] Will assume non-transactional DDL.
# [INFO] Context impl SQLiteImpl.
# [INFO] Will assume non-transactional DDL.
# [INFO] Running upgrade  -> 0001_assets, Initial assets schema
# Revision ID: 0001_assets
# Revises: None
# Create Date: 2025-12-10 00:00:00
# [INFO] Running upgrade 0001_assets -> 0002_merge_to_asset_references, Merge AssetInfo and AssetCacheState into unified asset_references table.
# [INFO] Running upgrade 0002_merge_to_asset_references -> 0003_add_metadata_job_id, Add system_metadata and job_id columns to asset_references.
# Change preview_id FK from assets.id to asset_references.id.
# [INFO] Running upgrade 0003_add_metadata_job_id -> 0004_drop_tag_type, Drop the vestigial tags.tag_type column.
# [INFO] Running upgrade 0004_drop_tag_type -> 0005_allow_case_sensitive_tags, Allow case-sensitive tag names.
# [INFO] Running upgrade 0005_allow_case_sensitive_tags -> 0006_add_loader_path, Add loader_path column to asset_references.
# [INFO] Running upgrade 0006_add_loader_path -> 0007_record_content_split, Record/content split.
# [INFO] Database upgraded from None to 0007_record_content_split
# [INFO] Using RAM pressure cache.
# [INFO] Starting server
#
# [INFO] To see the GUI go to: http://0.0.0.0:8188

# %%
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared-linux-amd64

# %%
# !./cloudflared-linux-amd64 tunnel --url http://localhost:8188 --no-autoupdate
# Out:
# 2026-09-24T13:19:40Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-09-24T13:19:40Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-09-24T13:19:43Z INF +--------------------------------------------------------------------------------------------+
# 2026-09-24T13:19:43Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2026-09-24T13:19:43Z INF |  https://present-murray-tutorials-ask.trycloudflare.com                                    |
# 2026-09-24T13:19:43Z INF +--------------------------------------------------------------------------------------------+
# 2026-09-24T13:19:43Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# 2026-09-24T13:19:43Z INF Version 2026.9.1 (Checksum 03f1f25d1cc93b9ad6c60569d44060bc4f17ed97075760ed8cfca4b12dcd68cc)
# 2026-09-24T13:19:43Z INF GOOS: linux, GOVersion: go1.26.8, GoArch: amd64
# 2026-09-24T13:19:43Z INF Settings: map[ha-connections:1 no-autoupdate:true protocol:quic url:http://localhost:8188]
# 2026-09-24T13:19:43Z INF cloudflared will not automatically update when run from the shell. To enable auto-updates, run cloudflared as a service: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps/configure-tunnels/local-management/as-a-service/
# 2026-09-24T13:19:43Z INF Generated Connector ID: abd05b45-1773-4390-b35a-b3f0d986db49
# 2026-09-24T13:19:43Z INF Initial protocol quic
# 2026-09-24T13:19:43Z INF ICMP proxy will use 172.19.2.2 as source for IPv4
# 2026-09-24T13:19:43Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026/09/24 13:19:43 failed to sufficiently increase receive buffer size (was: 208 kiB, wanted: 7168 kiB, got: 416 kiB). See https://github.com/quic-go/quic-go/wiki/UDP-Buffer-Sizes for details.
# 2026-09-24T13:19:43Z INF ICMP proxy will use 172.19.2.2 as source for IPv4
# 2026-09-24T13:19:43Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026-09-24T13:19:43Z INF Starting metrics server on 127.0.0.1:20241/metrics
# 2026-09-24T13:19:43Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveID(65074) CurveP256] connIndex=0 event=0 ip=198.41.200.63
# 2026-09-24T13:19:43Z INF Registered tunnel connection connIndex=0 connection=03216b77-9236-49b8-a00f-7a1549222a82 event=0 ip=198.41.200.63 location=ord11 protocol=quic
# 2026-09-24T13:19:49Z INF +-------------------------------------------------------------------------------------+
# 2026-09-24T13:19:49Z INF |                               CONNECTIVITY PRE-CHECKS                               |
# 2026-09-24T13:19:49Z INF +-------------------------------------------------------------------------------------+
# 2026-09-24T13:19:49Z INF |  COMPONENT         TARGET                     STATUS  DETAILS                       |
# 2026-09-24T13:19:49Z INF |  DNS Resolution    region1.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-09-24T13:19:49Z INF |  DNS Resolution    region2.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-09-24T13:19:49Z INF |  UDP Connectivity  region1.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-09-24T13:19:49Z INF |  UDP Connectivity  region2.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-09-24T13:19:49Z INF |  TCP Connectivity  region1.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-09-24T13:19:49Z INF |  TCP Connectivity  region2.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-09-24T13:19:49Z INF |  Cloudflare API    api.cloudflare.com:443     PASS    API is reachable              |
# 2026-09-24T13:19:49Z INF |                                                                                     |
# 2026-09-24T13:19:49Z INF |  SUMMARY: Environment is healthy. cloudflared will use 'quic' as primary protocol.  |
# 2026-09-24T13:19:49Z INF +-------------------------------------------------------------------------------------+
# 2026-09-24T13:19:49Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=cb8cc1bb-1262-4450-8ec3-efa7ef6331e7 status=pass target=region1.v2.argotunnel.com
# 2026-09-24T13:19:49Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=cb8cc1bb-1262-4450-8ec3-efa7ef6331e7 status=pass target=region2.v2.argotunnel.com
# 2026-09-24T13:19:49Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=cb8cc1bb-1262-4450-8ec3-efa7ef6331e7 status=pass target=region1.v2.argotunnel.com
# 2026-09-24T13:19:49Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=cb8cc1bb-1262-4450-8ec3-efa7ef6331e7 status=pass target=region2.v2.argotunnel.com
# 2026-09-24T13:19:49Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=cb8cc1bb-1262-4450-8ec3-efa7ef6331e7 status=pass target=region1.v2.argotunnel.com
# 2026-09-24T13:19:49Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=cb8cc1bb-1262-4450-8ec3-efa7ef6331e7 status=pass target=region2.v2.argotunnel.com
# 2026-09-24T13:19:49Z INF precheck component="Cloudflare API" details="API is reachable" run_id=cb8cc1bb-1262-4450-8ec3-efa7ef6331e7 status=pass target=api.cloudflare.com:443
# 2026-09-24T13:19:49Z INF precheck complete hard_fail=false run_id=cb8cc1bb-1262-4450-8ec3-efa7ef6331e7 suggested_protocol=quic
# [INFO] got prompt
# [INFO] model weight dtype torch.float16, manual cast: None
# [INFO] model_type EPS
# [INFO] Model storage policy: fast_disk=False paths=['/kaggle/working/ComfyUI/models/checkpoints/v1-5-pruned-emaonly.safetensors']
# [INFO] Model storage policy: fast_disk=False paths=['/kaggle/working/ComfyUI/models/checkpoints/v1-5-pruned-emaonly.safetensors']
# [INFO] Using pytorch attention in VAE
# [INFO] Using pytorch attention in VAE
# [INFO] VAE load device: cuda:0, offload device: cpu, dtype: torch.float32
# [INFO] Model storage policy: fast_disk=False paths=['/kaggle/working/ComfyUI/models/checkpoints/v1-5-pruned-emaonly.safetensors']
# [INFO] CLIP/text encoder model load device: cuda:0, offload device: cpu, current: cpu, dtype: torch.float16
# [INFO] Requested to load SD1ClipModel
# [INFO] Model SD1ClipModel prepared for dynamic VRAM loading. 235MB Staged. 0 patches attached. Force pre-loaded 50 weights: 150 KB.
# [INFO] Model SD1ClipModel prepared for dynamic VRAM loading. 235MB Staged. 0 patches attached. Force pre-loaded 50 weights: 150 KB.
# [INFO] Requested to load BaseModel
# [INFO] Model BaseModel prepared for dynamic VRAM loading. 1639MB Staged. 0 patches attached. Force pre-loaded 208 weights: 690 KB.
# 100%|██████████| 20/20 [00:03<00:00,  6.36it/s]
# [INFO] Requested to load AutoencoderKL
# [INFO] Model AutoencoderKL prepared for dynamic VRAM loading. 318MB Staged. 0 patches attached. Force pre-loaded 112 weights: 182 KB.
# [INFO] Prompt executed in 8.89 seconds
# [INFO] got prompt
# [INFO] Model SD1ClipModel prepared for dynamic VRAM loading. 235MB Staged. 0 patches attached. Force pre-loaded 50 weights: 150 KB.
# [INFO] Model BaseModel prepared for dynamic VRAM loading. 1639MB Staged. 0 patches attached. Force pre-loaded 208 weights: 690 KB.
# 100%|██████████| 20/20 [00:02<00:00,  6.96it/s]
# [INFO] Model AutoencoderKL prepared for dynamic VRAM loading. 318MB Staged. 0 patches attached. Force pre-loaded 112 weights: 182 KB.
# [INFO] Prompt executed in 3.90 seconds
# [INFO] got prompt
# [INFO] Model BaseModel prepared for dynamic VRAM loading. 1639MB Staged. 0 patches attached. Force pre-loaded 208 weights: 690 KB.
# 100%|██████████| 30/30 [00:04<00:00,  6.61it/s]
# [INFO] Model AutoencoderKL prepared for dynamic VRAM loading. 318MB Staged. 0 patches attached. Force pre-loaded 112 weights: 182 KB.
# [INFO] Prompt executed in 5.56 seconds
# [INFO] got prompt
# [INFO] Model SD1ClipModel prepared for dynamic VRAM loading. 235MB Staged. 0 patches attached. Force pre-loaded 50 weights: 150 KB.
# [INFO] Model BaseModel prepared for dynamic VRAM loading. 1639MB Staged. 0 patches attached. Force pre-loaded 208 weights: 690 KB.
# 100%|██████████| 30/30 [00:04<00:00,  6.53it/s]
# [INFO] Model AutoencoderKL prepared for dynamic VRAM loading. 318MB Staged. 0 patches attached. Force pre-loaded 112 weights: 182 KB.
# [INFO] Prompt executed in 5.66 seconds
# [INFO] got prompt
# [INFO] Model SD1ClipModel prepared for dynamic VRAM loading. 235MB Staged. 0 patches attached. Force pre-loaded 50 weights: 150 KB.
# [INFO] Model BaseModel prepared for dynamic VRAM loading. 1639MB Staged. 0 patches attached. Force pre-loaded 208 weights: 690 KB.
# 100%|██████████| 30/30 [00:04<00:00,  6.41it/s]
# [INFO] Model AutoencoderKL prepared for dynamic VRAM loading. 318MB Staged. 0 patches attached. Force pre-loaded 112 weights: 182 KB.
# [INFO] Prompt executed in 5.76 seconds
# [INFO] got prompt
# [INFO] Model BaseModel prepared for dynamic VRAM loading. 1639MB Staged. 0 patches attached. Force pre-loaded 208 weights: 690 KB.
# 100%|██████████| 30/30 [00:04<00:00,  6.48it/s]
# [INFO] Model AutoencoderKL prepared for dynamic VRAM loading. 318MB Staged. 0 patches attached. Force pre-loaded 112 weights: 182 KB.
# [INFO] Prompt executed in 5.64 seconds
# [INFO] got prompt
# [INFO] Model SD1ClipModel prepared for dynamic VRAM loading. 235MB Staged. 0 patches attached. Force pre-loaded 50 weights: 150 KB.
# [INFO] Model BaseModel prepared for dynamic VRAM loading. 1639MB Staged. 0 patches attached. Force pre-loaded 208 weights: 690 KB.
# 100%|██████████| 30/30 [00:04<00:00,  6.97it/s]
# [INFO] Model AutoencoderKL prepared for dynamic VRAM loading. 318MB Staged. 0 patches attached. Force pre-loaded 112 weights: 182 KB.
# [INFO] Prompt executed in 5.31 seconds
# [INFO] got prompt
# [INFO] Model BaseModel prepared for dynamic VRAM loading. 1639MB Staged. 0 patches attached. Force pre-loaded 208 weights: 690 KB.
# 100%|██████████| 30/30 [00:04<00:00,  7.18it/s]
# [INFO] Model AutoencoderKL prepared for dynamic VRAM loading. 318MB Staged. 0 patches attached. Force pre-loaded 112 weights: 182 KB.
# [INFO] Prompt executed in 5.11 seconds
# [INFO] got prompt
# [INFO] Model BaseModel prepared for dynamic VRAM loading. 1639MB Staged. 0 patches attached. Force pre-loaded 208 weights: 690 KB.
# 100%|██████████| 30/30 [00:04<00:00,  7.01it/s]
# [INFO] Model AutoencoderKL prepared for dynamic VRAM loading. 318MB Staged. 0 patches attached. Force pre-loaded 112 weights: 182 KB.
# [INFO] Prompt executed in 5.21 seconds
# [INFO] got prompt
# [INFO] Model BaseModel prepared for dynamic VRAM loading. 1639MB Staged. 0 patches attached. Force pre-loaded 208 weights: 690 KB.
# 100%|██████████| 30/30 [00:04<00:00,  6.90it/s]
# [INFO] Model AutoencoderKL prepared for dynamic VRAM loading. 318MB Staged. 0 patches attached. Force pre-loaded 112 weights: 182 KB.
# [INFO] Prompt executed in 5.33 seconds
